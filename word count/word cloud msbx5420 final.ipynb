# %%
# Import necessary libraries. 
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt

# %%
import os
os.getcwd()
# Out:
# '/Users/jenniferdickson'

# %%
df = pd.read_csv("Downloads/news.csv", index_col=0)

# %%
df.head()
# Out:
#                     authors  \
# 0              ['Cbc News']
# 1              ['Cbc News']
# 2  ['The Associated Press']
# 3              ['Cbc News']
# 4              ['Cbc News']
#
#                                                title         publish_date  \
# 0  Coronavirus a 'wake-up call' for Canada's pres...  2020-03-27 08:00:00
# 1  Yukon gov't names 2 possible sources of corona...  2020-03-27 01:45:00
# 2  U.S. Senate passes $2T coronavirus relief package  2020-03-26 05:13:00
# 3  Coronavirus: The latest in drug treatment and ...  2020-03-27 00:36:00
# 4  The latest on the coronavirus outbreak for Mar...  2020-03-26 20:57:00
#
#                                          description  \
# 0  Canadian pharmacies are limiting how much medi...
# 1  The Yukon government has identified two places...
# 2  The Senate has passed an unparalleled $2.2 tri...
# 3  Scientists around the world are racing to find...
# 4  The latest on the coronavirus outbreak from CB...
#
# ...

# %%
text = df.text[0]

# Create and generate a word cloud image:
wordcloud = WordCloud().generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
wordcloud = WordCloud(max_font_size=50, max_words=500, background_color="white").generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
text = " ".join(review for review in df.text)
print ("There are {} words in the combination of all descriptions.".format(len(text)))
# Out:
# There are 15796973 words in the combination of all descriptions.

# %%
stopwords = set(STOPWORDS)
stopwords.update(["said", "one", "many", "covid", "say","will","COVID", "says", "Canada", "wednesday", "thursday", "province", "https"])

# Generate a word cloud image
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)

# Display the generated image:
# the matplotlib way:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Total")
plt.show()
wordcloud.to_file("Downloads/total.png")

# %%
from datetime import date
import datetime

# %%
df.head()
# Out:
#                     authors  \
# 0              ['Cbc News']
# 1              ['Cbc News']
# 2  ['The Associated Press']
# 3              ['Cbc News']
# 4              ['Cbc News']
#
#                                                title         publish_date  \
# 0  Coronavirus a 'wake-up call' for Canada's pres...  2020-03-27 08:00:00
# 1  Yukon gov't names 2 possible sources of corona...  2020-03-27 01:45:00
# 2  U.S. Senate passes $2T coronavirus relief package  2020-03-26 05:13:00
# 3  Coronavirus: The latest in drug treatment and ...  2020-03-27 00:36:00
# 4  The latest on the coronavirus outbreak for Mar...  2020-03-26 20:57:00
#
#                                          description  \
# 0  Canadian pharmacies are limiting how much medi...
# 1  The Yukon government has identified two places...
# 2  The Senate has passed an unparalleled $2.2 tri...
# 3  Scientists around the world are racing to find...
# 4  The latest on the coronavirus outbreak from CB...
#
# ...

# %%
df2 = pd.read_csv("Downloads/news.csv", parse_dates = ['publish_date'],
                                       index_col = ['publish_date'],
                                       na_values = ['999.99'])
df2.head()
# Out:
#                      Unnamed: 0                   authors  \
# publish_date
# 2020-03-27 08:00:00           0              ['Cbc News']
# 2020-03-27 01:45:00           1              ['Cbc News']
# 2020-03-26 05:13:00           2  ['The Associated Press']
# 2020-03-27 00:36:00           3              ['Cbc News']
# 2020-03-26 20:57:00           4              ['Cbc News']
#
#                                                                  title  \
# publish_date
# 2020-03-27 08:00:00  Coronavirus a 'wake-up call' for Canada's pres...
# 2020-03-27 01:45:00  Yukon gov't names 2 possible sources of corona...
# 2020-03-26 05:13:00  U.S. Senate passes $2T coronavirus relief package
# 2020-03-27 00:36:00  Coronavirus: The latest in drug treatment and ...
# 2020-03-26 20:57:00  The latest on the coronavirus outbreak for Mar...
#
#                                                            description  \
# publish_date
# ...

# %%
feb = df2[df2.index.month == 2].head()
jan = df2[df2.index.month == 1].head()
mar = df2[df2.index.month == 3].head()
dec = df2[df2.index.month == 12].head()

# %%
textfeb = " ".join(review for review in feb.text)
textjan = " ".join(review for review in jan.text)
textmar = " ".join(review for review in mar.text)
textdec = " ".join(review for review in dec.text)

# %%
wordcloud2 = WordCloud(stopwords=stopwords, background_color="white").generate(textfeb)
plt.imshow(wordcloud2, interpolation='bilinear')
plt.axis("off")
plt.title("February")
wordcloud2.to_file("Downloads/feb.png")

# %%
wordcloud4 = WordCloud(stopwords=stopwords, background_color="white").generate(textdec)
plt.imshow(wordcloud4, interpolation='bilinear')
plt.axis("off")
plt.title("December")
wordcloud4.to_file("Downloads/dec.png")

# %%
wordcloud1 = WordCloud(stopwords=stopwords, background_color="white").generate(textmar)
plt.imshow(wordcloud1, interpolation='bilinear')
plt.axis("off")
plt.title("March")
wordcloud2.to_file("Downloads/mar.png")
